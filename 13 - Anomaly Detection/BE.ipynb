# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv("data/dataset.csv")
data['day'] = data['day_cycle_window'].astype(str).str[0]
data['cycle']= data['day_cycle_window'].astype(str).str[2]
data['window']= data['day_cycle_window'].astype(str).str[4:]
data
# Out:
#        day_cycle_window        p1        p2        p3        p4        p5  \
# 0                 1_1_1 -0.805191 -1.141993 -1.328327 -1.516693 -1.373962
# 1                 1_1_1 -0.805191 -1.134902 -1.320393 -1.505848 -1.361560
# 2                 1_1_1 -0.805191 -1.117304 -1.307167 -1.505848 -1.361560
# 3                 1_1_1 -0.814231 -1.114206 -1.287593 -1.442302 -1.287565
# 4                 1_1_1 -0.848104 -1.112276 -1.285393 -1.429076 -1.270722
# ...                 ...       ...       ...       ...       ...       ...
# 162697          4_4_160  0.147741  0.060913  0.185874 -0.163053 -0.284814
# 162698          4_4_160  0.147741  0.060913  0.185874 -0.163053 -0.284814
# 162699          4_4_160  0.147741  0.060913  0.185874 -0.163053 -0.284814
# 162700          4_4_160  0.147741  0.060913  0.185874 -0.163053 -0.232045
# 162701          4_4_160  0.196873  0.090617  0.292064 -0.132991 -0.219665
#
#               p6        p7        p8        p9       p10       p11 day cycle  \
# ...

# %%
data[data["day_cycle_window"] == "1_1_1"]
# Out:
#    day_cycle_window        p1        p2        p3        p4        p5  \
# 0             1_1_1 -0.805191 -1.141993 -1.328327 -1.516693 -1.373962
# 1             1_1_1 -0.805191 -1.134902 -1.320393 -1.505848 -1.361560
# 2             1_1_1 -0.805191 -1.117304 -1.307167 -1.505848 -1.361560
# 3             1_1_1 -0.814231 -1.114206 -1.287593 -1.442302 -1.287565
# 4             1_1_1 -0.848104 -1.112276 -1.285393 -1.429076 -1.270722
# ..              ...       ...       ...       ...       ...       ...
# 95            1_1_1 -1.757506 -2.486829 -2.667641 -2.951875 -3.142037
# 96            1_1_1 -1.771105 -2.486829 -2.667641 -2.924137 -3.056168
# 97            1_1_1 -1.781861 -2.480399 -2.653661 -2.906808 -2.918317
# 98            1_1_1 -1.803653 -2.471177 -2.634293 -2.876569 -2.890035
# 99            1_1_1 -1.804485 -2.471116 -2.634234 -2.875820 -2.888859
#
#           p6        p7        p8        p9       p10       p11 day cycle  \
# ...

# %%
def plot_param(cycle, param):
    plt.plot(data[data["day_cycle_window"] == cycle][param])

def query(cycle,param):
    return(np.array(data[data["day_cycle_window"] == cycle][param]))

# %%
for param in range(1,5): 
    for cycle in range(1,6):
        
        plt.figure(figsize=(30,8))
        for day in range(1,5):
            Y=[]
            for window in range(200):
                Y= np.concatenate((Y,(query(str(day)+'_'+str(cycle)+'_'+str(window),'p'+str(param)))))
            plt.plot(Y,label = 'day '+ str(day)) 
        plt.title('param'+str(param)+' cycle'+str(cycle))
        plt.legend()

# %%
def plot_day(param, day,df):
    Y = []
    for i in range(10):
        for j in range(200):
            Y = np.concatenate(
                (
                    Y,
                    np.array(
                        df[
                            df["day_cycle_window"]
                            == str(day) + "_" + str(i) + "_" + str(j)
                        ][param]
                    ),
                )
            )
            # print(str(day)+'_'+str(i)+'_'+str(j))
        # print(i)
    plt.plot([i for i in range(len(Y))], Y)
    # print(np.shape(Y))
"""

for j in range(1, 12):
    plt.figure(figsize=(30, 8))
    for i in range(1, 5):
        plot_day("p" + str(j), i)"""
# Out:
# '\n\nfor j in range(1, 12):\n    plt.figure(figsize=(30, 8))\n    for i in range(1, 5):\n        plot_day("p" + str(j), i)'

# %%
data_count = data.groupby(["day_cycle_window"]).agg(['count'])['p1']

errors = data_count[data_count['count'] !=100]
errors.index

clean_data = data 
for i in errors.index:
    clean_data = clean_data.drop(clean_data.index[clean_data['day_cycle_window'] == i ])
clean_data
# Out:
#        day_cycle_window        p1        p2        p3        p4        p5  \
# 0                 1_1_1 -0.805191 -1.141993 -1.328327 -1.516693 -1.373962
# 1                 1_1_1 -0.805191 -1.134902 -1.320393 -1.505848 -1.361560
# 2                 1_1_1 -0.805191 -1.117304 -1.307167 -1.505848 -1.361560
# 3                 1_1_1 -0.814231 -1.114206 -1.287593 -1.442302 -1.287565
# 4                 1_1_1 -0.848104 -1.112276 -1.285393 -1.429076 -1.270722
# ...                 ...       ...       ...       ...       ...       ...
# 162621          4_4_159 -0.966581 -1.312164 -1.272253 -1.466330 -1.263788
# 162622          4_4_159 -0.969980 -1.311966 -1.277075 -1.471689 -1.263653
# 162623          4_4_159 -0.975743 -1.311966 -1.284710 -1.471689 -1.263439
# 162624          4_4_159 -0.981632 -1.311966 -1.284710 -1.471689 -1.263439
# 162625          4_4_159 -0.990592 -1.311966 -1.284710 -1.473564 -1.263439
#
#               p6        p7        p8        p9       p10       p11
# ...

# %%
for j in range(1, 12):
    plt.figure(figsize=(30, 8))
    for i in range(1, 5):
        plot_day("p" + str(j), i,clean_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4835/4064289514.py in <module>
#       2     plt.figure(figsize=(30, 8))
#       3     for i in range(1, 5):
# ----> 4         plot_day("p" + str(j), i,clean_data)
#
# /tmp/ipykernel_4835/2125271930.py in plot_day(param, day, df)
#       8                     np.array(
#       9                         df[
# ---> 10                             df["day_cycle_window"]
#      11                             == str(day) + "_" + str(i) + "_" + str(j)
#      12                         ][param]
#
# ~/miniconda3/envs/graph/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...
